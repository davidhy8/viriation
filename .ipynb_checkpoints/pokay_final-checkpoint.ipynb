# %% [markdown]
# # Download and import needed packages

# %%
# !pip install metapub

# %%
# !pip install lxml[html_clean]

# %%
# !pip install ratelimit

# %%
# !pip install lxml

# %%
# !pip install html5lib

# %%
# !pip install selenium

# %%
# !apt-get update

# %%
# !pip install requests_html

# %%
# !pip install pytest-playwright

# %% [markdown]
# # Specify global variables
# Define any regular expressions and dictionaries that will be needed later on

# %%
# Process text files with Regular Expressions
import re

# Retreive files from online
import urllib.request

# Access files inside the folder directory
from pathlib import Path

# Create dictionaries with lists as values
from collections import defaultdict

# %%
# Specify NCBI API KEY
# %env NCBI_API_KEY="6667a919224612da1287d74ff0d3f7b5e208"
# Out:
# env: NCBI_API_KEY="6667a919224612da1287d74ff0d3f7b5e208"

# %%
# Regex format of DOI links, mutations, blocks, and literature type
doi_pattern = r'https:\/\/doi\.org\/[\w/.-]+'
mutation_pattern = r'(.*)?\n\n'
block_pattern = r'(?:(?<=\n\n)|^)(.+?)(?=\n\n|\Z)'
literature_pattern = r'(?<=\[)(.*?)(?=\])'
url_pattern = r'https:\/\/[^\s]+'

# %%
# Dictionary of doi to BioC JSON files 
publication_bioc = {}
grey_bioc = {}
rxiv_bioc = {}

# Dictionary of doi to pokay mutation summaries from that article
publication_key = defaultdict(list)
grey_key = defaultdict(list)
rxiv_key = defaultdict(list)

# %% [markdown]
# # Read through Pokay directory and categorize by article type
# Iterate through the Pokay data directory and sort the entries into their respective dictionaries depending on if they are
# - Journal article,
# - Preprint, or
# - Grey literature.

# %%
# Retreive all files from Pokay directory
directory = '/home/david.yang1/autolit/litcovid/data/pokay'
files = Path(directory).glob('*/*')

# %%
# Iterate through all files in the pokay directory
for file in files:
    with open(file, 'r') as f:
    
        # Read file
        file_contents = f.read()

        # Find all mutations
        # mutations = re.findall(mutation_pattern, file_contents)

        # Find all text blocks
        text_blocks = re.findall(block_pattern, file_contents, re.DOTALL)

        # Iterate through all text blocks
        for text in text_blocks:
            
            # Define the article type
            article_type = re.findall(literature_pattern, text)
            
            # If no article type provided, check format of the link
            if len(article_type)==0:
                url = re.search(url_pattern, text)
                if url:
                    doi = re.search(doi_pattern, url.group())
                    if doi:
                        rxiv_key[doi.group()].append(text)
                        rxiv_bioc[doi.group()] = None
                    else:
                        grey_key[url.group()].append(text)
                        grey_bioc[url.group()] = None
                continue

            if "Journal publication" in article_type:
                # Search for the DOI of the publication
                doi = re.search(doi_pattern, text).group()
                publication_key[doi].append(text)
                publication_bioc[doi] = None
                
            elif "Preprint" in article_type[-1]:
                # Check if new DOI is provided
                doi = re.search(doi_pattern, article_type[-1])

                # Check if Rxiv is now published
                if doi is not None:
                    publication_key[doi.group()].append(text)
                    publication_bioc[doi.group()] = None

                # Store as Rxiv
                else:
                    doi = re.search(doi_pattern, text)
                    # DOI link provided
                    if doi is not None:
                        rxiv_key[doi.group()].append(text)
                        rxiv_bioc[doi.group()] = None
                    # DOI link not provided
                    else: 
                        rxiv_key[re.search(url_pattern, text).group()].append(text)
                        rxiv_bioc[re.search(url_pattern, text).group()] = None

            # Check if the article is grey literature
            elif article_type[-1] == "Grey literature":
                # Search for url link
                url = re.search(url_pattern, text)
                if url is not None:
                    grey_key[url.group()].append(text)
                    grey_bioc[url.group()] = None
            
            # All other groups categorize as grey literature
            else:
                url = re.search(url_pattern, text)
                if url is not None:
                    grey_key[url.group()].append(text)
                    grey_bioc[url.group()] = None

# %% [markdown]
# # Obtain BioC JSON files for the links
#
# **get_pubtator_bioc_json(id)**: retrieves the BioC JSON files using the Pubtator API with PMID. Returns None if the API call fails.
#
# **get_pmid(doi)**: converts the papers doi to pmid. Returns None if it cannot be converted.

# %%
# Convert DOI to PMID
from metapub.convert import doi2pmid

# BioC JSON API calls
import requests

# Limit the number of API calls to 10 per second
from ratelimit import limits, sleep_and_retry

from bs4 import BeautifulSoup

# %%
# Obtain BioC JSON file from PMID or PMC with a maximum of 3 API calls per second

@sleep_and_retry
@limits(calls=3, period=1)
def get_pubtator_bioc_json(id):
    # API link for BioC
    url = "https://www-ncbi-nlm-nih-gov.ezproxy.lib.ucalgary.ca/research/bionlp/RESTful/pmcoa.cgi/BioC_json/" + str(id) + "/unicode"
    bioc = requests.get(url, allow_redirects=True)

    # Failed to grab BioC
    if bioc.status_code != 200:
        raise ConnectionError('could not download {}\nerror code: {}'.format(url, bioc.status_code))
        return None
    
    return bioc.content.decode('utf-8')

# %%
# Obtain PMID ID from DOI link with a maximum of 3 API calls per second

@sleep_and_retry
@limits(calls=3, period=1)
def get_pmid(doi):
    # pmid = doi2pmid(doi)
    doi_part = doi.split('doi.org/')[-1]

    # Api link for paper details
    api_link = 'https://www-ncbi-nlm-nih-gov.ezproxy.lib.ucalgary.ca/pmc/utils/idconv/v1.0/?tool=doi2pmid&email=david.yang1@ucalgary.ca&ids=' + doi_part
    paper = requests.get(api_link)
    soup = BeautifulSoup(paper.content, "xml")
        
    pmid = soup.find('record')['pmid']
    return pmid

# %% [markdown]
# # Download ArXiv XML (JATS) files of the articles for conversion
# https://github.com/PeerJ/jats-conversion/blob/master/src/data/xsl/jats-to-pubmed.xsl
#
# **get_arxiv_details(doi)**: grab details of papers from Rxiv using Rxiv API with DOI url. Return None if API call fails.
#
# **get_arxiv_pmid(doi)**: grab PMID for papers from Rxiv using DOI url.
#
# **get_arxiv_published_doi(details)**: grab published DOI from the Rxiv details
#
# **get_arxiv_jats_xml(details)**: grab the JATS XML for the Rxiv paper

# %%
import json

# %%
@sleep_and_retry
@limits(calls=1, period=1)
def get_medrxiv_details(doi):
    doi_part = doi.split('doi.org/')[-1]
    api_link = 'https://api.medrxiv.org/details/medrxiv/' + doi_part
    preprint_details = requests.get(api_link)
    
    if preprint_details.status_code != 200:
        raise ConnectionError('could not download {}\nerror code: {}'.format(api_link, preprint_details.status_code))
        return None
    
    return preprint_details.content

# %%
@sleep_and_retry
@limits(calls=1, period=1)
def get_biorxiv_details(doi):
    doi_part = doi.split('doi.org/')[-1]
    api_link = 'https://api.biorxiv.org/details/biorxiv/' + doi_part
    preprint_details = requests.get(api_link)
    
    if preprint_details.status_code != 200:
        raise ConnectionError('could not download {}\nerror code: {}'.format(api_link, preprint_details.status_code))
        return None
    
    return preprint_details.content

# %%
@sleep_and_retry
@limits(calls=3, period=1)
def get_biorxiv_pmid(doi):
    details = get_biorxiv_details(doi).decode('utf-8')
    
    pmid = None
    
    # Load the JSON data
    data = json.loads(details)

    title = data['collection'][0]['title']
    modified_title = title.replace(" ", "%20")
    pubmed_link = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&retmode=json&retmax=1000&term=" + modified_title + "&field=title"
    
    data_json = requests.get(pubmed_link).content.decode('utf-8')
    data = json.loads(data_json)
    pmid = data['esearchresult']['idlist'][0]

    return pmid

# %%
@sleep_and_retry
@limits(calls=3, period=1)
def get_medrxiv_pmid(doi):
    details = get_medrxiv_details(doi).decode('utf-8')
    
    pmid = None
    
    # Load the JSON data
    data = json.loads(details)

    title = data['collection'][0]['title']
    modified_title = title.replace(" ", "%20")
    pubmed_link = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&retmode=json&retmax=1000&term=" + modified_title + "&field=title"
    
    data_json = requests.get(pubmed_link).content.decode('utf-8')
    data = json.loads(data_json)
    pmid = data['esearchresult']['idlist'][0]

    return pmid

# %%
def get_arxiv_published_doi(details):
    data = json.loads(details)

    # Check if it is published
    if "published" in data["collection"][0]:
        doi = "https://doi.org/" + data['collection'][0]['published']
        return doi
    else:
        return None

# %%
def get_arxiv_jats_xml(details):
    data = json.loads(details)
    jatsxml_url = data['collection'][0]['jatsxml']
    jats_xml = requests.get(jatsxml_url).content.decode('utf-8')
    return jats_xml

# %% [markdown]
# # Convert JATS XML file to HTML
#
# Using XSLT conversions
#
# https://pypi.org/project/bioconverters/
#
# https://github.com/ncbi/PubReader
# https://github.com/lfurrer/bconv?tab=readme-ov-file

# %%
import lxml.etree as ET

# %%
def convert_jatsxml_to_html(input_file, output_file):
    # dom = ET.parse(input_file)
    dom = ET.fromstring(jats_xml)
    xslt = ET.parse('jats-to-html.xsl')
    transform = ET.XSLT(xslt)
    newdom = transform(dom)
    newdom.write_output(output_file)

# %%
# convert_jatsxml_to_html("output.xml", "results.html")

# %% [markdown]
# # Convert links in the dictionaries to BioC JSON format
#
# Conversion possibilities include:
# - Journal DOI to BioC JSON
# - Preprint DOI to Jats XML to HTML to BioC JSON
# - Grey literature HTML to BioC JSON

# %% [markdown]
# ## Journal publications

# %%
cannot_convert_journal = 0
total = 0

# Convert the DOI links to PMID and then grab them in BioC JSON format
for key in publication_bioc:
    total += 1
    bioc = None

    if total > 5:
        break
    
    try:
        # Convert to PMID
        pmid = get_pmid(key)
        bioc = get_pubtator_bioc_json(pmid)
    except:
        # Alternative way to get bioc
        # print(key)
        cannot_convert_journal += 1

    if bioc == "[]":
        bioc = None
    
    publication_bioc[key] = bioc
        
    
    # Retreive BioC JSON if conversion successful
    # if pmid:
    #     grey_bioc[key] = get_pubtator_bioc_json(pmid)

    # Convert manually if unsucessful
    # else:
        # Convert into PMID
    #     pmid = scrape_PMID(key)

        # Could not scrape PMID from PubMed, therefore generate BioC JSON
    #     if pmid is None:
            # Make your own BioC JSON file instead
    #         json = make_bioc_json(key)
            
        # Retreive BioC JSON
    #     grey_bioc[key]=get_bioc_json(pmid)

# %%
sum = 0 
for key in publication_bioc:
    if publication_bioc[key] is not None:
        sum += 1

# %% [markdown]
# ## Rxiv preprints

# %%
# cannot_convert_m1 = 0

# cannot_convert_m2 = 0
total = 0

# Convert the DOI links to PMID and then grab them in BioC JSON format
for key in rxiv_bioc:
    total += 1
    bioc = None
    converted = False
    biorxiv = True
    details = None
        
    # Get PMID as BioRxiv
    try:
        # Convert to PMID
        pmid = get_biorxiv_pmid(key)
        bioc = get_pubtator_bioc_json(pmid)
    except:
        # cannot_convert_m1 += 1
        # converted = False
        pass

    # Get PMID as MedRxiv
    try:
        # Convert to PMID
        pmid = get_medrxiv_pmid(key)
        bioc = get_pubtator_bioc_json(pmid)
    except:
        # cannot_convert_m1 += 1
        # converted = False
        pass
    

    # Successful, goto next key
    if bioc and bioc != "[]":
        rxiv_bioc[key] = bioc
        continue

    # Try to get details as BioRxiv
    try: 
        details = get_biorxiv_details(key).decode('utf-8')

    except:
        biorxiv = False
        converted = False

    if details:
        status = json.loads(details)
        status = status['messages'][0]['status']

        if status != 'ok': 
            biorxiv = False
    
    # Try to get details as MedRxiv
    if biorxiv == False:
        try:
            details = get_medrxiv_details(key).decode('utf-8')
        except:
            continue

    # Convert to PMID then BioC using another tool
    try:
        # Convert to DOI then PMID then BioC
        doi = get_arxiv_published_doi(details)
        pmid = get_pmid(doi)
        bioc = get_pubtator_bioc_json(pmid)
        converted = True
    except:
        # cannot_convert_m2 += 1
        converted = False
        bioc = None

    # Retreive JATS XML then convert to HTML for later conversions
    if converted == False or bioc == "[]":
        try:
            jats_xml = get_arxiv_jats_xml(details)
            file_name = key.split('doi.org/')[-1]
            # Replace . in DOI with -
            file_name = file_name.replace(".", "-")
            # Replace / in DOI with _
            file_name = file_name.replace("/", "_")
            output_file = 'Auto-CORPus/input/' + file_name + ".html"
            convert_jatsxml_to_html(jats_xml, output_file)
            bioc = "converting"
        except:
            bioc = None

    rxiv_bioc[key] = bioc
# Out:
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter
# enter

# %%
key = 'https://doi.org/10.1101/2022.06.24.22276144'
# key = 'https://doi.org/10.1101/2023.04.04.535604'
details = None 
converted = False
bioc = None
biorxiv = True

try: 
    details = get_biorxiv_details(key).decode('utf-8')

except:
    biorxiv = False
    converted = False
    print("not biorxiv")
print(details)

if details:
    status = json.loads(details)
    status = status['messages'][0]['status']

    if status != 'ok': 
        biorxiv = False
print(status)
print(biorxiv)

# Try to get details as MedRxiv
if biorxiv == False:
    print("inside")
    try:
        details = get_medrxiv_details(key).decode('utf-8')
    except:
        pass


if converted == False or bioc == "[]":
    try:
        jats_xml = get_arxiv_jats_xml(details)
        print(jats_xml)
            # file_name = key.split('doi.org/')[-1]
            # Replace . in DOI with -
            # file_name = file_name.replace(".", "-")
            # Replace / in DOI with _
            # file_name = file_name.replace("/", "_")
            # output_file = 'Auto-CORPus/input/' + file_name + ".html"
            # convert_jatsxml_to_html(jats_xml, output_file)
        bioc = "converting"
    except:
        bioc = None
        print("fail")

# details = get_medrxiv_details('https://doi.org/10.1101/2022.06.24.22276144').decode('utf-8')
# print(details)
# jats_xml = get_arxiv_jats_xml(details)
# jats_xml

# %%
sum = 0 
for key in rxiv_bioc:
    if rxiv_bioc[key] is not None:
        sum += 1
    else:
        # Manually process preprints that are not from Rxiv
        # Do this with wget -O out.html download_link.com

        file_name = key.split('doi.org/')[-1]
        # Replace . in DOI with -
        file_name = file_name.replace(".", "-")
        # Replace / in DOI with _
        file_name = file_name.replace("/", "_")
        print(file_name)
        print(key)
        print(" ")
sum
# Out:
# 10-21203_rs-3-rs-400230_v1
# https://doi.org/10.21203/rs.3.rs-400230/v1
#
# 10-1101_2021-02-03-429164v4
# https://doi.org/10.1101/2021.02.03.429164v4
#
# 10-21203_rs-3-rs-226857_v1
# https://doi.org/10.21203/rs.3.rs-226857/v1
#
# https:__www-researchgate-net_publication_348943694_The_mutation_P681H_in_the_B117_variant_of_SARS-CoV-2_probably_enhances_viral_entry_and_replication
# https://www.researchgate.net/publication/348943694_The_mutation_P681H_in_the_B117_variant_of_SARS-CoV-2_probably_enhances_viral_entry_and_replication
#
# 10-21203_rs-3-rs-318392_v1
# https://doi.org/10.21203/rs.3.rs-318392/v1
#
# 10-1101_2021-03-09-434607v9
# https://doi.org/10.1101/2021.03.09.434607v9
#
# 10-1101_2021-12-24-21268382v1-full
# https://doi.org/10.1101/2021.12.24.21268382v1.full
#
# https:__virological-org_t_emergence-of-y453f-and-69-70hv-mutations-in-a-lymphoma-patient-with-long-term-covid-19_580
# https://virological.org/t/emergence-of-y453f-and-69-70hv-mutations-in-a-lymphoma-patient-with-long-term-covid-19/580
#
# 10-1128_msphere-00104-21
# https://doi.org/10.1128/msphere.00104-21
#
# 10-1038_s41467-020-20321-x
# https://doi.org/10.1038/s41467-020-20321-x
# 49

# %% [markdown]
# # Preprints that couldn't be retrieved
# (**Manually go through**)
#
# (NOW PUBLISHED)
# 10-21203_rs-3-rs-400230_v1
# https://doi.org/10.21203/rs.3.rs-400230/v 1
#
# 10-1101_2021-02-03-429164v4
# https://doi.org/10.1101/2021.02.03.429164v4
#
# 10-21203_rs-3-rs-226857_v1
# https://doi.org/10.21203/rs.3.rs-226857/v1
#
# https:__www-researchgate-net_publication_348943694_The_mutation_P681H_in_the_B117_variant_of_SARS-CoV-2_probably_enhances_viral_entry_and_replication
# https://www.researchgate.net/publication/348943694_The_mutation_P681H_in_the_B117_variant_of_SARS-CoV-2_probably_enhances_viral_entry_and_replication
#
# 10-21203_rs-3-rs-318392_v1
# https://doi.org/10.21203/rs.3.rs-318392/v1
#
# 10-1101_2021-03-09-434607v9
# https://doi.org/10.1101/2021.03.09.434607v9
#
# 10-1101_2021-12-24-21268382v1-full
# https://doi.org/10.1101/2021.12.24.21268382v1.full
#
# https:__virological-org_t_emergence-of-y453f-and-69-70hv-mutations-in-a-lymphoma-patient-with-long-term-covid-19_580
# https://virological.org/t/emergence-of-y453f-and-69-70hv-mutations-in-a-lymphoma-patient-with-long-term-covid-19/580
#
# 10-1128_msphere-00104-21
# https://doi.org/10.1128/msphere.00104-21
#
# 10-1038_s41467-020-20321-x
# https://doi.org/10.1038/s41467-020-20321-xg/10.1038/s41467-020-20321-x
# 10-1038_s41467-020-20321-x
# 10-1038_s41467-020-20321-x

# %%
# Preprint 1
# Special doi
key = 'https://doi.org/10.21203/rs.3.rs-400230/v1'
doi = 'https://doi-org.ezproxy.lib.ucalgary.ca/10.1038/s41467-021-24909-9'
doi_part = doi.split('.ca/')[-1]

# Api link for paper details
api_link = 'https://www-ncbi-nlm-nih-gov.ezproxy.lib.ucalgary.ca/pmc/utils/idconv/v1.0/?tool=doi2pmid&email=david.yang1@ucalgary.ca&ids=' + doi_part
paper = requests.get(api_link)
soup = BeautifulSoup(paper.content, "xml")        
pmid = soup.find('record')['pmid']

bioc = get_pubtator_bioc_json(pmid)

rxiv_bioc[key] = bioc

# %%
# Preprint 2 
key = 'https://doi.org/10.1101/2021.02.03.429164v4'

# Not found manually search up online
# Special doi
doi = 'https://doi-org.ezproxy.lib.ucalgary.ca/10.1038/s41587-022-01382-3'

doi_part = doi.split('.ca/')[-1]

# Api link for paper details
api_link = 'https://www-ncbi-nlm-nih-gov.ezproxy.lib.ucalgary.ca/pmc/utils/idconv/v1.0/?tool=doi2pmid&email=david.yang1@ucalgary.ca&ids=' + doi_part
paper = requests.get(api_link)
soup = BeautifulSoup(paper.content, "xml")        
pmid = soup.find('record')['pmid']

bioc = get_pubtator_bioc_json(pmid)

rxiv_bioc[key] = bioc

# %%
# Preprint 3
key = 'https://doi.org/10.21203/rs.3.rs-226857/v1'

# Special doi
doi = 'https://doi-org.ezproxy.lib.ucalgary.ca/10.1038/s41467-021-25167-5'

doi_part = doi.split('.ca/')[-1]

# Api link for paper details
api_link = 'https://www-ncbi-nlm-nih-gov.ezproxy.lib.ucalgary.ca/pmc/utils/idconv/v1.0/?tool=doi2pmid&email=david.yang1@ucalgary.ca&ids=' + doi_part
paper = requests.get(api_link)
soup = BeautifulSoup(paper.content, "xml")        
pmid = soup.find('record')['pmid']

bioc = get_pubtator_bioc_json(pmid)

rxiv_bioc[key] = bioc

# %%
# Preprint 4
key = 'https://www.researchgate.net/publication/348943694_The_mutation_P681H_in_the_B117_variant_of_SARS-CoV-2_probably_enhances_viral_entry_and_replication'

# Downloaded as PDF

# %%
# Preprint 5
key = 'https://doi.org/10.21203/rs.3.rs-318392/v1'

# Downloaded as PDF

# %%
# Preprint 6
key = 'https://doi.org/10.1101/2021.03.09.434607v9'

# Not found manually search up online
doi = 'https://doi.org/10.1101/2021.03.09.434607'

details = get_biorxiv_details(doi).decode('utf-8')

jats_xml = get_arxiv_jats_xml(details)

rxiv_bioc[key] = "converting"

# %%
# Preprint 7

# %% [markdown]
# ## Grey literature
#
# Manually convert

# %%
grey_bioc
# Out:
# {'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/1009243/Technical_Briefing_20.pdf': None,
#  'https://doi.org/10.15585/mmwr.mm7017e2': None,
#  'https://doi.org/10.1101/2021.04.30.441559': None,
#  'https://doi.org/10.1101/2022.05.11.491588': None,
#  'https://doi.org/10.47326/ocsat.dashboard.2021.1.0': None,
#  'https://www.covid19genomics.dk/2021-05-08_data-overview.html#b1525': None,
#  'https://observablehq.com/@aglucaci/sc2-omicron': None,
#  'https://www.fda.gov/media/155050/download': None}
